# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pickle as p

with open("first_site_ids.p", "rb") as f:
    ids_raw = p.load(f)

_, ids_list = zip(*ids_raw)
ids = [item for li in ids_list for item in li]

# %%
cd FirstSite
# Out:
# /Users/ForgeGreensboro/Documents/Upwork/FirstSite

# %%
from FirstSite import FirstSite

# %%
d = FirstSite(ids)

# %%
d.send_emails("Seth", "sethsemailscraper@gmail.com", "Hello, my name is Seth and I am interested in your product.")
# Out:
#  0 1 2 3 4 5
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-12-6c26d50163be> in <module>()
# ----> 1 d.send_emails("Seth", "sethsemailscraper@gmail.com", "Hello, my name is Seth and I am interested in your product.")
#
# /Users/ForgeGreensboro/Documents/Upwork/FirstSite/FirstSite.py in send_emails(self, name, email, text, number)
#      50                 time.sleep(rand.random())
#      51             for letter in email:
# ---> 52                 form_email.send_keys(letter)
#      53                 time.sleep(rand.random())
#      54             for letter in number:
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/selenium/webdriver/remote/webelement.pyc in send_keys(self, *value)
#     318                 value = self._upload(local_file)
#     319
# ...

# %%
ids
# Out:
# [u'200190837',
#  u'203021424',
#  u'200193288',
#  u'146783266',
#  u'125385558',
#  u'195406564',
#  u'187404610',
#  u'202946282',
#  u'99580378',
#  u'127818776',
#  u'201407713',
#  u'203261498',
#  u'195763717',
#  u'199999294',
#  u'181935379',
#  u'199640190',
#  u'202772175',
#  u'182317012',
#  u'182780338',
#  u'181273166',
#  u'201284700',
#  u'202677911',
#  u'180957866',
#  u'195131634',
#  u'182512014',
#  u'184310836',
#  u'160835480',
#  u'149650762',
#  u'179651891',
#  u'152844324',
#  u'186259001',
#  u'174807968',
#  u'184140553',
#  u'180956951',
#  u'201282126',
#  u'203991455',
#  u'198047081',
#  u'175718037',
#  u'190520026',
#  u'182278258',
#  u'203993419',
#  u'203785819',
#  u'203035504',
#  u'173507392',
#  u'201586934',
#  u'201587646',
#  u'195522185',
#  u'138303708',
#  u'111193095',
#  u'202040384',
#  u'203491358',
#  u'185504203',
#  u'201289735',
#  u'152944004',
#  u'160704887',
#  u'200210655',
#  u'196073253',
#  u'142830943',
# ...
